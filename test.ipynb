# %%
import pandas as pd
df = pd.read_csv("results.csv", header = None, names=["device_token", "event_type", "event_date", "received_date", "controller_date", "c1", "c2", "c3"])
df["total_duration"] = df["controller_date"]-df["event_date"]
df["received_duration"] = df["received_date"]-df["event_date"]
df["controller_duration"] = df["controller_date"]-df["received_date"]
df[["controller_duration", "received_duration", "total_duration"]].plot()
# Out:
# <AxesSubplot: >

# %%
df.describe()
# Out:
#          event_date  received_date  controller_date   c1   c2   c3  \
# count  6.601000e+03   6.601000e+03     6.601000e+03  0.0  0.0  0.0
# mean   1.670958e+15   1.670958e+15     1.670958e+15  NaN  NaN  NaN
# std    1.834874e+07   1.835192e+07     1.835342e+07  NaN  NaN  NaN
# min    1.670958e+15   1.670958e+15     1.670958e+15  NaN  NaN  NaN
# 25%    1.670958e+15   1.670958e+15     1.670958e+15  NaN  NaN  NaN
# 50%    1.670958e+15   1.670958e+15     1.670958e+15  NaN  NaN  NaN
# 75%    1.670958e+15   1.670958e+15     1.670958e+15  NaN  NaN  NaN
# max    1.670958e+15   1.670958e+15     1.670958e+15  NaN  NaN  NaN
#
#        total_duration  received_duration  controller_duration
# count     6601.000000        6601.000000          6601.000000
# mean     38804.608696       26005.180882         12799.427814
# std      30177.197738       22344.859187         13172.279193
# min      18397.000000        9309.000000          8055.000000
# 25%      26934.000000       16383.000000          8916.000000
# 50%      30878.000000       20177.000000          9381.000000
# 75%      37771.000000       25929.000000         11648.000000
# max     358840.000000      239667.000000        141156.000000

# %%
import seaborn as sns
sns.relplot(data=df, x="event_date", y="controller_duration")
